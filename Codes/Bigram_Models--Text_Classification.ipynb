# %% [markdown]
# ### Importing all relevant packages

# %%
import pandas as pd

# %%
from sklearn.model_selection import train_test_split

# %%
from pprint import pprint

# %%
from collections import Counter

# %%
from collections import OrderedDict

# %%
from nltk.corpus import stopwords
stopwords = list(stopwords.words('english'))

# %%
spacy_stopwords = list(spacy.lang.en.stop_words.STOP_WORDS)

# %%
spacy_stopwords.extend(stopwords)
spacy_stopwords = list(set(spacy_stopwords))

# %%
spacy_stopwords.index('us')
# Out:
# 113

# %%
spacy_stopwords.extend(['got','told','said','tell','mr','don'])

# %%
import numpy as np

# %%
import spacy

# %%
nlp = spacy.load('en')

# %%
import pickle

# %%
from sklearn.metrics import accuracy_score

# %% [markdown]
# ### Understanding the data and categories

# %% [markdown]
# BBC articles data taken from here
# * https://www.kaggle.com/yufengdev/bbc-text-categorization

# %%
data = pd.read_csv('../Data/bbc-text.csv',encoding='latin1',index_col=False)

# %%
data.shape
# Out:
# (2225, 2)

# %%
data.head()
# Out:
#         category                                               text
# 0           tech  tv future in the hands of viewers with home th...
# 1       business  worldcom boss  left books alone  former worldc...
# 2          sport  tigers wary of farrell  gamble  leicester say ...
# 3          sport  yeading face newcastle in fa cup premiership s...
# 4  entertainment  ocean s twelve raids box office ocean s twelve...

# %%
categories = data.category.unique()

# %%
data.category.value_counts()
# Out:
# sport            511
# business         510
# politics         417
# tech             401
# entertainment    386
# Name: category, dtype: int64

# %% [markdown]
# ### Pre-process Text Content

# %%
def bigrams(input_list):
    bigrams_list = list(zip(input_list,input_list[1:]))
    bigrams_list_2 = [element for element in bigrams_list if element !=('STOP','START') and element !=('START','STOP')]
    return bigrams_list_2

# %%
def preprocess_text(text):
    doc = nlp(text)
    sentences = [each_sent for each_sent in doc.sents]
    lol_words = [
    [
        str(each_token.lemma_) for each_token in nlp(each_sent.text) 
        if str(each_token) not in spacy_stopwords and each_token.is_punct==False and each_token.is_space==False
    ] 
    for each_sent in doc.sents
    ]
    lol_words_proper = [['START']+each_sent+['STOP'] for each_sent in lol_words]
    lol_words_proper_unfurl = [each_word for each_sent in lol_words_proper for each_word in each_sent]
    bigrams_list = bigrams(lol_words_proper_unfurl)
    unigrams_list = [element for element in lol_words_proper_unfurl if element!='START' and element!='STOP']
    return (unigrams_list,bigrams_list)

# %% [markdown]
# ### Training and testing on the whole data

# %% [markdown]
# ###### Splitting the data into train and test data

# %%
train,test = train_test_split(data,test_size=0.1)

# %%
train.head()
# Out:
#            category                                               text
# 1116       business  stormy year for property insurers a string of ...
# 2             sport  tigers wary of farrell  gamble  leicester say ...
# 2039  entertainment  russian film wins bbc world prize russian dram...
# 1110           tech  what high-definition will do to dvds first it ...
# 925        business  man utd to open books to glazer manchester uni...

# %%
test.head()
# Out:
#            category                                               text
# 2186       business  battered dollar hits another low the dollar ha...
# 1415           tech  row brewing over peer-to-peer ads music downlo...
# 987   entertainment  john peel replacement show begins the permanen...
# 577           sport  hearts of oak 3-2 cotonsport hearts of oak set...
# 1676       politics  gurkhas to help tsunami victims britain has of...

# %%
train.reset_index(drop=True,inplace=True)

# %%
test.reset_index(drop=True,inplace=True)

# %% [markdown]
# ###### Calculate bigram counts for each class (training)

# %%
count_bigrams_cat = {}
count_unigrams_cat = {}
vocab_size_cat = {}

# %%
def training_bigrams(category,df):
    bigrams_list = []
    unigrams_list = []
    ans = [preprocess_text(text) for text in df.text]
    for each in ans:
        bigrams_list.extend(each[1])
        unigrams_list.extend(each[0])
    vocab_size_cat[category] = len(list(set(unigrams_list)))
    count_bigrams_cat[category] = Counter(bigrams_list)
    count_unigrams_cat[category] = Counter(unigrams_list)

# %% [markdown]
# ###### Assigning class based on highest log-probability score on new dataset (.predict function equivalent)

# %% [markdown]
# <img src="images/add delta smoothed conditional prob.png" style="width:150;height:150px;">

# %%
def bigram_markov(new_sent):
    ans = preprocess_text(new_sent)
    bigrams_list = ans[1]
    unigrams_list = ans[0]
    markov_prob = {}
    for cat in categories:
        markov_prob[cat] = 0
        for each in bigrams_list:
            markov_prob[cat] += np.log((count_bigrams_cat[cat][each]+0.1)/(count_unigrams_cat[cat][each[0]]+0.1*vocab_size_cat[cat]))
        if len(new_sent.split())>0:
            markov_prob[cat] = markov_prob[cat]/len(new_sent.split())
    markov_prob_final = sorted(markov_prob.items(),key=lambda x:x[1], reverse=True)
    return markov_prob_final

# %%
#data_test = data.copy()
#data_test = data_test.sample(n=100)

# %%
#data_test.category.value_counts()

# %%
# %%time
# training now on the train data
train.groupby('category').apply(lambda df: training_bigrams(df.name,df))
# Out:
# Wall time: 6min 18s
# Empty DataFrame
# Columns: []
# Index: []

# %%
# pickle dump for quicker reuse later
vocab_size_cat_f = open("../Data/vocab_size_train.pkl",'wb')
count_bigrams_cat_f = open("../Data/bigram_count_train.pkl",'wb')
count_unigrams_cat_f = open("../Data/unigrams_count_train.pkl",'wb')

pickle.dump(vocab_size_cat,vocab_size_cat_f)
pickle.dump(count_bigrams_cat,count_bigrams_cat_f)
pickle.dump(count_unigrams_cat,count_unigrams_cat_f)

vocab_size_cat_f.close()
count_bigrams_cat_f.close()
count_unigrams_cat_f.close()

# %%
# vocab_size_cat = pickle.load("../Data/vocab_size.pkl")
# count_bigrams_cat = pickle.load("../Data/vocab_size.pkl")
# count_unigrams_cat = pickle.load("../Data/vocab_size.pkl")

# %% [markdown]
# ###### A quick look at the Bigram Markov Model Features

# %%
print(vocab_size_cat)
print("****")
pprint(list(zip(categories,[count_bigrams_cat[cat].most_common(5) for cat in categories])))
print("****")
pprint(list(zip(categories,[count_unigrams_cat[cat].most_common(5) for cat in categories])))
# Out:
# {'business': 9283, 'entertainment': 8898, 'politics': 8317, 'sport': 8083, 'tech': 8765}
# ****
# [('tech',
#   [(('e', 'mail'), 178),
#    (('mobile', 'phone'), 154),
#    (('year', 'STOP'), 135),
#    (('START', 'people'), 92),
#    (('bbc', 'news'), 85)]),
#  ('business',
#   [(('year', 'STOP'), 236),
#    (('START', 'company'), 122),
#    (('chief', 'executive'), 117),
#    (('START', 'analyst'), 96),
#    (('interest', 'rate'), 93)]),
#  ('sport',
#   [(('game', 'STOP'), 151),
#    (('START', 'think'), 145),
#    (('START', 'know'), 107),
#    (('time', 'STOP'), 101),
#    (('year', 'STOP'), 97)]),
#  ('entertainment',
#   [(('year', 'STOP'), 133),
#    (('START', 'film'), 96),
#    (('award', 'STOP'), 94),
#    (('film', 'STOP'), 84),
#    (('box', 'office'), 79)]),
#  ('politics',
#   [(('prime', 'minister'), 250),
#    (('START', 'blair'), 175),
#    (('START', 'tory'), 165),
#    (('tony', 'blair'), 161),
#    (('lib', 'dem'), 160)])]
# ****
# [('tech',
#   [('people', 849),
#    ('game', 652),
#    ('mobile', 575),
#    ('technology', 567),
#    ('phone', 483)]),
#  ('business',
#   [('year', 828),
#    ('$', 730),
#    ('company', 575),
#    ('firm', 488),
#    ('market', 461)]),
#  ('sport',
#   [('game', 582), ('play', 538), ('win', 534), ('good', 467), ('time', 433)]),
#  ('entertainment',
#   [('film', 807), ('good', 643), ('year', 548), ('award', 483), ('star', 406)]),
#  ('politics',
#   [('government', 710),
#    ('labour', 706),
#    ('party', 676),
#    ('election', 625),
#    ('people', 596)])]

# %% [markdown]
# ###### Testing on some sample sentences

# %%
bigram_markov("economic growth slows down")
# Out:
# [('business', -3.9692388514802905),
#  ('politics', -6.7677569438805945),
#  ('tech', -8.341093396600021),
#  ('sport', -9.000286606679415),
#  ('entertainment', -9.09610496174359)]

# %%
bigram_markov("prime minister")
# Out:
# [('politics', -3.5746871267381852),
#  ('business', -7.440089097987748),
#  ('tech', -10.252850263607193),
#  ('sport', -11.981405120960808),
#  ('entertainment', -12.124273481509913)]

# %%
bigram_markov("halo was hugely successful")
# Out:
# [('tech', -6.2126216117651065),
#  ('politics', -7.672317862538664),
#  ('sport', -8.01886399230171),
#  ('business', -8.157525044723988),
#  ('entertainment', -8.502447051556878)]

# %% [markdown]
# ###### Testing on the whole dataset and measuring accuracy

# %%
test.head()
# Out:
#         category                                               text
# 0       business  battered dollar hits another low the dollar ha...
# 1           tech  row brewing over peer-to-peer ads music downlo...
# 2  entertainment  john peel replacement show begins the permanen...
# 3          sport  hearts of oak 3-2 cotonsport hearts of oak set...
# 4       politics  gurkhas to help tsunami victims britain has of...

# %%
def bigram_markov_final(new_sent):
    ans = preprocess_text(new_sent)
    bigrams_list = ans[1]
    unigrams_list = ans[0]
    markov_prob = {}
    for cat in categories:
        markov_prob[cat] = 0
        for each in bigrams_list:
            markov_prob[cat] += np.log((count_bigrams_cat[cat][each]+0.1)/(count_unigrams_cat[cat][each[0]]+0.1*vocab_size_cat[cat]))
        if len(new_sent.split())>0:
            markov_prob[cat] = markov_prob[cat]/len(new_sent.split())
    markov_prob_final = sorted(markov_prob.items(),key=lambda x:x[1], reverse=True)
    return markov_prob_final[0][0]

# %%
test.index
# Out:
# RangeIndex(start=0, stop=223, step=1)

# %%
# %%time
test['predicted'] = test.apply(lambda x: bigram_markov_final(x.text),axis=1)
# Out:
# C:\Users\welcome\Anaconda3\envs\MLDLNLP_1\lib\site-packages\ipykernel_launcher.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   """Entry point for launching an IPython kernel.
# Wall time: 44.5 s

# %%
test.head()
# Out:
#         category                                               text  \
# 0       business  battered dollar hits another low the dollar ha...
# 1           tech  row brewing over peer-to-peer ads music downlo...
# 2  entertainment  john peel replacement show begins the permanen...
# 3          sport  hearts of oak 3-2 cotonsport hearts of oak set...
# 4       politics  gurkhas to help tsunami victims britain has of...
#
#        predicted
# 0       business
# 1           tech
# 2  entertainment
# 3          sport
# 4       politics

# %%
print(accuracy_score(test['category'],test['predicted']))
# Out:
# 0.968609865470852

# %% [markdown]
# 97% accuracy for prediction of category

# %% [markdown]
# ###### Appendix - Understanding the bigram features

# %%
count_bigrams_cat.keys()
# Out:
# dict_keys(['business', 'entertainment', 'politics', 'sport', 'tech'])

# %% [markdown]
# ###### Bigram Features

# %%
df = pd.DataFrame([count_bigrams_cat['tech'].most_common(50),count_bigrams_cat['sport'].most_common(50),count_bigrams_cat['entertainment'].most_common(50),count_bigrams_cat['business'].most_common(50),count_bigrams_cat['politics'].most_common(50)]).T
df.columns = ['tech','sport','entertainment','business','politics']
df
# Out:
#                             tech                     sport  \
# 0               ((e, mail), 178)       ((game, STOP), 151)
# 1         ((mobile, phone), 154)     ((START, think), 145)
# 2            ((year, STOP), 135)      ((START, know), 107)
# 3          ((START, people), 92)       ((time, STOP), 101)
# 4              ((bbc, news), 85)        ((year, STOP), 97)
# 5       ((START, microsoft), 82)      ((season, STOP), 97)
# 6             ((game, STOP), 80)       ((START, good), 96)
# 7          ((START, mobile), 79)    ((START, england), 88)
# 8            ((START, game), 76)       ((grand, slam), 88)
# 9          ((website, STOP), 75)       ((START, play), 87)
# 10         ((news, website), 72)      ((new, zealand), 82)
# 11           ((phone, STOP), 69)        ((world, cup), 81)
# 12      ((technology, STOP), 68)       ((START, want), 77)
# 13      ((high, definition), 67)      ((player, STOP), 77)
# 14                  ((3, g), 67)       ((START, feel), 67)
# 15           ((let, people), 65)              ((6, 3), 65)
# 16         ((service, STOP), 64)         ((win, STOP), 64)
# 17            ((START, new), 64)        ((play, STOP), 64)
# 18            ((time, STOP), 62)  ((champion, league), 64)
# 19          ((START, apple), 62)              ((7, 6), 61)
# 20           ((START, sony), 57)        ((week, STOP), 61)
# 21           ((month, STOP), 56)         ((START, go), 60)
# 22           ((START, year), 56)        ((bbc, sport), 60)
# 23        ((search, engine), 55)  ((australian, open), 59)
# 24        ((START, company), 54)       ((match, STOP), 59)
# 25        ((software, STOP), 54)              ((6, 7), 56)
# 26           ((anti, virus), 52)       ((START, look), 56)
# 27          ((system, STOP), 51)      ((second, half), 54)
# 28         ((network, STOP), 51)         ((add, STOP), 53)
# 29           ((hard, drive), 50)      ((injury, STOP), 53)
# 30           ((video, game), 50)              ((6, 4), 52)
# 31            ((site, STOP), 49)        ((good, STOP), 52)
# 32          ((device, STOP), 48)      ((START, great), 52)
# 33            ((2005, STOP), 48)        ((davis, cup), 51)
# 34          ((START, think), 48)        ((club, STOP), 51)
# 35             ((mac, mini), 47)       ((final, STOP), 50)
# 36           ((high, speed), 46)              ((6, 2), 48)
# 37  ((consumer, electronic), 46)        ((team, STOP), 47)
# 38         ((music, player), 45)              ((3, 6), 46)
# 39                ((wi, fi), 45)     ((world, number), 46)
# 40         ((START, accord), 44)    ((START, ireland), 46)
# 41           ((START, want), 44)      ((minute, STOP), 45)
# 42         ((program, STOP), 44)     ((england, STOP), 44)
# 43           ((START, time), 43)       ((sport, STOP), 44)
# 44       ((START, consumer), 43)        ((START, lot), 43)
# 45           ((START, user), 43)        ((START, win), 43)
# 46           ((world, STOP), 43)       ((START, come), 42)
# 47            ((work, STOP), 42)        ((come, STOP), 41)
# 48          ((online, STOP), 42)       ((START, game), 41)
# 49        ((START, service), 42)    ((START, roddick), 41)
#
#                entertainment                    business  \
# 0        ((year, STOP), 133)         ((year, STOP), 236)
# 1        ((START, film), 96)     ((START, company), 122)
# 2        ((award, STOP), 94)   ((chief, executive), 117)
# 3         ((film, STOP), 84)      ((START, analyst), 96)
# 4        ((box, office), 79)      ((interest, rate), 93)
# 5       ((START, think), 63)         ((START, firm), 90)
# 6        ((START, year), 62)        ((market, STOP), 84)
# 7          ((new, york), 54)       ((stock, market), 75)
# 8    ((million, dollar), 52)    ((economic, growth), 73)
# 9        ((START, good), 52)          ((2004, STOP), 69)
# 10           ((take, $), 49)         ((month, STOP), 65)
# 11      ((dollar, baby), 48)       ((economy, STOP), 64)
# 12        ((good, film), 46)          ((2005, STOP), 61)
# 13        ((name, good), 45)          ((2003, STOP), 59)
# 14       ((vera, drake), 45)        ((START, yukos), 59)
# 15       ((music, STOP), 45)    ((deutsche, boerse), 58)
# 16    ((good, director), 42)          ((oil, price), 53)
# 17       ((START, band), 41)        ((report, STOP), 53)
# 18     ((good, actress), 41)   ((START, government), 49)
# 19       ((los, angele), 41)     ((stock, exchange), 49)
# 20        ((START, new), 40)           ((new, york), 48)
# 21        ((good, song), 40)        ((growth, STOP), 47)
# 22    ((film, festival), 39)       ((company, STOP), 45)
# 23        ((time, STOP), 39)        ((START, china), 44)
# 24         ((add, STOP), 38)         ((START, year), 43)
# 25         ((win, good), 37)         ((START, bank), 43)
# 26    ((academy, award), 36)       ((START, accord), 43)
# 27    ((february, STOP), 36)          ((START, new), 42)
# 28       ((START, know), 35)  ((consumer, spending), 41)
# 29       ((START, want), 35)      ((business, STOP), 41)
# 30          ((25, year), 35)       ((START, figure), 39)
# 31       ((jamie, foxx), 34)      ((START, economy), 39)
# 32       ((good, actor), 34)         ((START, sale), 38)
# 33       ((prize, STOP), 34)           ((add, STOP), 38)
# 34      ((START, oscar), 33)        ((START, think), 37)
# 35    ((START, british), 33)      ((START, despite), 37)
# 36     ((good, support), 33)           ((say, STOP), 37)
# 37     ((golden, globe), 32)     ((statement, STOP), 36)
# 38       ((joss, stone), 32)          ((sale, STOP), 36)
# 39      ((number, STOP), 31)        ((news, agency), 36)
# 40       ((START, time), 31)          ((firm, STOP), 35)
# 41      ((START, actor), 31)           ((year, ago), 35)
# 42          ((hip, hop), 31)     ((fourth, quarter), 35)
# 43  ((martin, scorsese), 30)           ((START, uk), 35)
# 44         ((START, uk), 30)          ((sri, lanka), 35)
# 45       ((award, good), 30)       ((country, STOP), 34)
# 46       ((chart, STOP), 30)          ((cost, STOP), 34)
# 47        ((2003, STOP), 29)      ((START, country), 34)
# 48        ((life, STOP), 29)        ((START, share), 32)
# 49  ((franz, ferdinand), 29)          ((rate, rise), 32)
#
#                        politics
# 0      ((prime, minister), 250)
# 1         ((START, blair), 175)
# 2          ((START, tory), 165)
# 3          ((tony, blair), 161)
# 4             ((lib, dem), 160)
# 5    ((general, election), 158)
# 6    ((liberal, democrat), 148)
# 7        ((START, labour), 148)
# 8       ((election, STOP), 146)
# 9        ((START, howard), 119)
# 10   ((START, government), 117)
# 11     ((michael, howard), 116)
# 12          ((year, STOP), 108)
# 13     ((home, secretary), 105)
# 14        ((human, right), 101)
# 15         ((kilroy, silk), 99)
# 16         ((START, brown), 96)
# 17         ((START, think), 95)
# 18           ((START, lib), 87)
# 19        ((gordon, brown), 85)
# 20       ((START, liberal), 81)
# 21  ((START, conservative), 77)
# 22           ((START, add), 76)
# 23         ((START, prime), 72)
# 24           ((bbc, radio), 72)
# 25         ((START, party), 72)
# 26            ((add, STOP), 72)
# 27         ((tory, leader), 68)
# 28     ((government, STOP), 66)
# 29        ((country, STOP), 66)
# 30         ((council, tax), 66)
# 31        ((labour, party), 64)
# 32   ((election, campaign), 64)
# 33          ((party, STOP), 64)
# 34          ((START, lord), 61)
# 35      ((public, service), 61)
# 36             ((radio, 4), 59)
# 37       ((START, kennedy), 59)
# 38           ((START, bbc), 58)
# 39           ((week, STOP), 58)
# 40            ((START, ms), 57)
# 41        ((START, people), 55)
# 42          ((issue, STOP), 53)
# 43       ((minister, STOP), 53)
# 44       ((campaign, STOP), 53)
# 45            ((bbc, news), 53)
# 46   ((foreign, secretary), 52)
# 47            ((tax, STOP), 51)
# 48          ((START, want), 51)
# 49      ((leader, michael), 50)

# %% [markdown]
# ###### Unigram Features

# %%
df = pd.DataFrame([count_unigrams_cat['tech'].most_common(50),count_unigrams_cat['sport'].most_common(50),count_unigrams_cat['entertainment'].most_common(50),count_unigrams_cat['business'].most_common(50),count_unigrams_cat['politics'].most_common(50)]).T
df.columns = ['tech','sport','entertainment','business','politics']
df
# Out:
#                   tech            sport      entertainment           business  \
# 0        (people, 849)      (game, 582)        (film, 807)        (year, 828)
# 1          (game, 652)      (play, 538)        (good, 643)           ($, 730)
# 2        (mobile, 575)       (win, 534)        (year, 548)     (company, 575)
# 3    (technology, 567)      (good, 467)       (award, 483)        (firm, 488)
# 4         (phone, 483)      (time, 433)        (star, 406)      (market, 461)
# 5           (new, 474)      (year, 430)       (music, 398)        (rise, 407)
# 6          (year, 470)    (player, 424)     (include, 307)        (sale, 384)
# 7       (service, 460)   (england, 411)         (new, 291)        (bank, 372)
# 8          (user, 437)     (world, 372)       (actor, 231)      (growth, 356)
# 9           (use, 394)         (6, 358)        (band, 229)     (economy, 355)
# 10     (computer, 372)     (match, 326)        (song, 220)         (new, 355)
# 11          (net, 355)      (come, 318)          (uk, 218)       (share, 341)
# 12         (firm, 353)      (team, 305)      (number, 211)  (government, 313)
# 13     (software, 346)        (go, 301)        (play, 210)       (price, 307)
# 14       (system, 325)     (final, 298)    (director, 207)    (economic, 305)
# 15        (music, 324)    (second, 295)        (take, 204)       (month, 286)
# 16      (digital, 317)      (club, 274)       (album, 203)        (rate, 285)
# 17         (time, 317)       (cup, 267)        (time, 198)     (country, 278)
# 18      (company, 315)       (new, 259)           ($, 191)        (2004, 274)
# 19         (work, 308)       (set, 254)          (tv, 190)        (fall, 264)
# 20         (like, 306)   (ireland, 246)       (oscar, 189)      (expect, 259)
# 21          (way, 305)     (think, 244)     (british, 184)        (high, 258)
# 22         (site, 294)  (champion, 243)       (chart, 182)    (business, 258)
# 23       (player, 285)      (take, 237)      (people, 172)      (report, 253)
# 24        (world, 277)      (half, 234)         (win, 160)     (analyst, 248)
# 25           (uk, 275)    (injury, 230)      (record, 159)         (oil, 236)
# 26      (million, 273)     (coach, 229)      (singer, 158)       (state, 233)
# 27      (network, 272)      (want, 227)     (actress, 157)        (time, 218)
# 28        (video, 269)    (season, 219)         (bbc, 155)       (world, 215)
# 29       (online, 264)      (wale, 219)          (go, 155)         (000, 215)
# 30         (find, 254)     (start, 216)     (million, 154)       (chief, 214)
# 31    (microsoft, 254)       (old, 211)        (come, 150)         (big, 210)
# 32         (good, 246)    (france, 208)        (work, 145)        (cost, 207)
# 33      (website, 243)       (add, 205)     (release, 141)    (increase, 207)
# 34         (help, 243)      (look, 204)         (big, 138)      (profit, 201)
# 35         (high, 241)     (rugby, 200)         (hit, 138)       (china, 200)
# 36       (number, 240)       (try, 198)    (festival, 137)       (group, 192)
# 37       (device, 238)    (minute, 194)       (prize, 136)        (euro, 189)
# 38     (consumer, 229)      (week, 193)         (day, 135)         (cut, 188)
# 39     (internet, 226)      (open, 192)      (single, 127)      (dollar, 187)
# 40        (offer, 224)      (like, 186)       (movie, 126)         (tax, 184)
# 41         (want, 222)      (goal, 185)        (role, 126)        (deal, 183)
# 42           (tv, 222)      (know, 183)       (think, 125)   (financial, 182)
# 43         (mail, 222)   (victory, 182)        (like, 122)          (uk, 182)
# 44  (information, 220)      (beat, 181)  (nomination, 121)      (figure, 180)
# 45       (market, 219)     (great, 180)         (man, 120)        (good, 177)
# 46    (broadband, 213)   (olympic, 180)         (000, 119)   (executive, 176)
# 47       (search, 212)      (lose, 178)        (know, 117)        (2005, 176)
# 48          (say, 211)    (nation, 173)       (place, 117)        (plan, 174)
# 49         (look, 210)    (chance, 171)      (comedy, 116)        (come, 170)
#
#                politics
# 0     (government, 710)
# 1         (labour, 706)
# 2          (party, 676)
# 3       (election, 625)
# 4         (people, 596)
# 5       (minister, 521)
# 6          (blair, 503)
# 7           (tory, 493)
# 8           (plan, 444)
# 9           (year, 414)
# 10           (new, 401)
# 11           (say, 361)
# 12           (tax, 344)
# 13         (brown, 341)
# 14            (uk, 324)
# 15          (lord, 316)
# 16        (howard, 299)
# 17        (public, 294)
# 18            (mp, 278)
# 19          (work, 274)
# 20          (time, 272)
# 21         (issue, 270)
# 22          (want, 262)
# 23          (home, 261)
# 24        (leader, 260)
# 25     (secretary, 258)
# 26         (right, 254)
# 27         (prime, 252)
# 28       (country, 251)
# 29       (britain, 248)
# 30         (claim, 241)
# 31          (come, 240)
# 32           (law, 240)
# 33           (bbc, 238)
# 34  (conservative, 232)
# 35            (go, 231)
# 36          (need, 226)
# 37       (general, 221)
# 38    (chancellor, 220)
# 39          (vote, 220)
# 40      (campaign, 218)
# 41         (think, 213)
# 42           (add, 208)
# 43          (good, 205)
# 44       (service, 202)
# 45        (change, 195)
# 46        (police, 195)
# 47        (report, 190)
# 48           (000, 190)
# 49       (council, 188)
